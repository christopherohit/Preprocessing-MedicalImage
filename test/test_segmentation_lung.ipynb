# %%
from src.utils.modelUnet import unet
from src.utils.PlotMask import SegmentImage

model = unet()
model.load_weights('/home/ai_car/Preprocessing-MedicalImage/model/cxr_reg_weights.best.hdf5')

# %%
from PIL import Image
import numpy as np
image = Image.open('/home/ai_car/Preprocessing-MedicalImage/image/00003349_000.png')
image = image.resize((256,256))
ima = np.asarray(image)
type(ima)
# Out:
# numpy.ndarray

# %%
path = '/home/ai_car/Preprocessing-MedicalImage/image/00003349_000.png'

# %%
maskapply, masked_image, chest_image = SegmentImage(model= model,
                                                    path= path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-e28383ea54b3> in <module>
#       1 maskapply, masked_image, chest_image = SegmentImage(model= model,
# ----> 2                                                     path= path)
#
# ~/Preprocessing-MedicalImage/src/utils/PlotMask.py in SegmentImage(model, path, img_shape, threshold)
#      79     x = x.astype(np.float32)
#      80     x = np.expand_dims(x, axis=0)
# ---> 81     y_pred = model.predict(x)[0] > threshold
#      82     y_pred = y_pred.astype(np.int32)
#      83     plt.imsave('mask.jpeg',np.squeeze(y_pred),cmap='gray')
#
# ~/anaconda3/envs/DLevaluation/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1439
#    1440         # Case 2: Symbolic tensors or Numpy array-like.
# ...

# %%
image.resize((256,256))
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F0B39F153C8>

# %%
imag = ima.reshape(1, ima.shape[0], ima.shape[1], 1)

# %%
imag.shape
# Out:
# (1, 256, 256, 1)

# %%
a = model.predict(imag)

# %%
a = a.reshape(a.shape[1], a.shape[2])

# %%
a.shape
# Out:
# (256, 256)

# %%
import cv2
import matplotlib.pyplot as plt
plt.imshow(a)
